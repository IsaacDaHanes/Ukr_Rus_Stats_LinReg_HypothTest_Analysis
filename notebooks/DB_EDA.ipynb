# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt

# %%
conflict_data_ukr = pd.read_csv('../data/conflict_data/conflict_data_ukr.csv')
conflict_data_ukr.head()
# Out:
#          id               relid        year  active_year code_status  \
# 0       NaN                 NaN  #date+year          NaN         NaN
# 1  147997.0  UKR-2014-1-14085-0        2014          1.0       Clear
# 2  149221.0  UKR-2014-1-14085-1        2014          1.0       Clear
# 3  149248.0  UKR-2014-1-14085-3        2014          1.0       Clear
# 4  149249.0  UKR-2014-1-14085-4        2014          1.0       Clear
#
#    type_of_violence  conflict_dset_id  conflict_new_id        conflict_name  \
# 0               NaN               NaN              NaN                  NaN
# 1               1.0           13219.0          13219.0  Ukraine: Government
# 2               1.0           13219.0          13219.0  Ukraine: Government
# 3               1.0           13219.0          13219.0  Ukraine: Government
# 4               1.0           13219.0          13219.0  Ukraine: Government
#
#    dyad_dset_id  ...                 date_end deaths_a  deaths_b  \
# ...

# %%
ukraineconflict = pd.read_csv('../data/conflict_data/UkraineConflict.csv')
ukraineconflict.head()
# Out:
#   EVENT_ID_CNTY      EVENT_DATE  YEAR  TIME_PRECISION           DISORDER_TYPE  \
# 0        ROU448     20-May-2019  2019               1      Political violence
# 1       ROU1885   28-March-2022  2022               1  Strategic developments
# 2       ROU1940    28-July-2022  2022               1          Demonstrations
# 3       ROU1945    31-July-2022  2022               1  Strategic developments
# 4       ROU1947  04-August-2022  2022               1          Demonstrations
#
#                    EVENT_TYPE         SUB_EVENT_TYPE  \
# 0  Violence against civilians                 Attack
# 1      Strategic developments  Disrupted weapons use
# 2                    Protests       Peaceful protest
# 3      Strategic developments  Disrupted weapons use
# 4                    Protests       Peaceful protest
#
#                                              ACTOR1 ASSOC_ACTOR_1  INTER1  \
# 0  Police Forces of Romania (2016-2019) Coast Guard           NaN       1
# ...

# %%
cumulative_loss_value = pd.read_csv('../data/losses/cummulative_loss_value.csv')
cumulative_loss_value.head()
# Out:
#    Unnamed: 0     date    aircraft  helicopter        tank         APC  \
# 0           0  2022-02   435000000   232000000   180000000   326400000
# 1           1  2022-03  2025000000  1048000000   736800000   694000000
# 2           2  2022-04  2850000000  1240000000  1209600000   978000000
# 3           3  2022-05  3120000000  1392000000  1629600000  1320800000
# 4           4  2022-06  3255000000  1480000000  1887600000  1490400000
#
#    field artillery        MRL     drone  naval ship  anti-aircraft warfare  \
# 0         44400000   16800000    300000    20000000               25000000
# 1        186600000   76800000   8300000    70000000              270000000
# 2        261600000  120800000  23200000   890000000              385000000
# 3        389400000  165600000  51500000   900000000              465000000
# 4        474000000  196800000  64100000   900000000              520000000
#
#    military auto
# 0       23280000
# 1       96080000
# 2      136080000
# ...

# %%
tweets = pd.read_csv('../data/Tweets/tweets.csv', dtype=object)
tweets.head()
# Out:
#                 Tweet Id                                          Tweet URL  \
# 0  "1562659745852321793"  https://twitter.com/zur_hausen/status/15626597...
# 1  "1562659689422520321"  https://twitter.com/MuluTes96885364/status/156...
# 2  "1562659549735034880"  https://twitter.com/Iness054193682/status/1562...
# 3  "1562659177167593474"  https://twitter.com/koolkustmer/status/1562659...
# 4  "1562659176966651906"  https://twitter.com/Tsrha_Kw/status/1562659176...
#
#       Tweet Posted Time                                      Tweet Content  \
# 0  25 Aug 2022 04:34:50  "Kann mir mal jemand erklären, warum junge, we...
# 1  25 Aug 2022 04:34:37  "#TigrayUnderAttack \n#StopWarOnTigray \n#Ukra...
# 2  25 Aug 2022 04:34:04  "Zelensky: “Un attacco missilistico russo cont...
# 3  25 Aug 2022 04:32:35  "Russia so Engaged in Ukrainian War, America b...
# 4  25 Aug 2022 04:32:35  "#TigrayUnderAttack \n#StopWarOnTigray \n#Ukra...
#
# ...
